# %%
import sys
import os

project_path = os.path.join(os.getcwd(), "SEM_PROJECT_MASTER")

if project_path not in sys.path:
    sys.path.insert(0, project_path)

# %%
import importlib
import ai_engine.tryon_engine
import app

importlib.reload(ai_engine.tryon_engine)
importlib.reload(app)
# Out:
# <module 'app' from 'c:\\Shubranil\\College\\Notes\\Sem-2\\Sem - 2 Minor Project\\V-Mirror\\SEM_PROJECT_MASTER\\app.py'>

# %%
from app import app
app.run(debug=True, use_reloader=False)
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Aug/2026 19:38:05] "GET / HTTP/1.1" 302 -
# 127.0.0.1 - - [06/Aug/2026 19:38:05] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2026 19:38:05] "GET /static/css/auth.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2026 19:38:06] "GET /static/js/auth.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2026 19:38:06] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Aug/2026 19:38:18] "POST /login HTTP/1.1" 401 -
# 127.0.0.1 - - [06/Aug/2026 19:38:22] "GET /signup HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Aug/2026 19:38:22] "GET /static/css/auth.css HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Aug/2026 19:38:22] "GET /static/js/auth.js HTTP/1.1" 304 -
# 127.0.0.1 - - [06/Aug/2026 19:38:45] "POST /signup HTTP/1.1" 200 -
# ...
